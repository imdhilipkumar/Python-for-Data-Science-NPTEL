# %%
a= 2
b = '2'

# %% [markdown]
# Variable declaration

# %%
a=2
x=2.0
b=3
y= 4.0

# %%
c=a

# %%
print(c)
# Out:
# 2

# %%
sum_ab=a+b  #summation of two variables a and b
mult_bc=b*c #multiplication
power = b**c  #power

# %%
print("Sum of a and b = ",sum_ab)
# Out:
# Sum of a and b =  5

# %%
print("Multiplication of b and c =",mult_bc)
print("b to the power c = ", power)
# Out:
# Multiplication of b and c = 6
# b to the power c =  9

# %%
2+2
# Out:
# 4

# %%
17 // 3
# Out:
# 5

# %%
17 / 3
# Out:
# 5.666666666666667

# %%
17 % 3
# Out:
# 2

# %%
5 * 3 + 2
# Out:
# 17

# %%
width = 20
height = 5 * 9
width * height
# Out:
# 900

# %%
a = 12
b = 30

# %%
print(a>b)
# Out:
# False

# %%
print(a < b)
print(a == b)
print(a != b) #this comparison opertor is for not equal to
print(a >= b)
print(a <= b)
# Out:
# True
# False
# True
# False
# True

# %% [markdown]
# Logical operators

# %%
x = True
y = False

# %%
print(x and y)
# Out:
# False

# %%
a = 100
b = a

# %%
b += a

# %%
print(b)
# Out:
# 200

# %%
a = 12

# %%
type(a)
# Out:
# int

# %%
a = 12.00

# %%
type(a)
# Out:
# float

# %%
5%11
# Out:
# 5

# %% [markdown]
# the precedence of operators is and > or > not
# and
# Returns True if both conditions are true. For example, (x > 3) and (y < 15) returns True if both x > 3 and y < 15 are true.
# or
# Returns True if at least one condition is true. For example, (x > 10) or (y < 25) returns True if either x > 10 or y < 25 is true.
# not
# Inverts the truth value of a condition. For example, not (x > 10) returns True if x > 10 is false.

# %% [markdown]
# 0. :=
#  1. lambda
#  2. if – else
#  3. or
#  4. and
#  5. not x
#  6. in, not in, is, is not, <, <=, >, >=, !=, ==
#  7. |
#  8. ^
#  9. &
# 10. <<, >>
# 11. +, -
# 12. *, @, /, //, %
# 13. +x, -x, ~x
# 14. **
# 14. await x
# 15. x[index], x[index:index], x(arguments...), x.attribute
# 16. (expressions...), [expressions...], {key: value...}, {expressions...}

# %%
12-4 * (16//2**4)+32
# Out:
# 40

# %%
a = 3
b = '12'
print(a*b)
# Out:
# 121212

# %%
a = -9//7

# %%
a
# Out:
# -2
