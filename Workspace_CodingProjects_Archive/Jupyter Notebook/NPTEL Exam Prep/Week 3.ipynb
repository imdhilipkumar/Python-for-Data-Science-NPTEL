# %%
import os
os.chdir(r"D:\Code-Hero-Hub\PYTHON\Data Science\Python for Data Science\NPTEL Exam Prep\Week 3")

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("hotel_bookings.csv")

# %%
data
# Out:
#               hotel  is_canceled  arrival_date_year arrival_date_month  \
# 0      Resort Hotel            0               2015               July
# 1      Resort Hotel            0               2015               July
# 2      Resort Hotel            0               2015               July
# 3      Resort Hotel            0               2015               July
# 4      Resort Hotel            0               2015               July
# ...             ...          ...                ...                ...
# 40055    City Hotel            0               2015             August
# 40056    City Hotel            0               2015             August
# 40057    City Hotel            0               2015             August
# 40058    City Hotel            0               2015             August
# 40059    City Hotel            0               2015             August
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# ...

# %%
data.isnull().sum()
# Out:
# hotel                            0
# is_canceled                      0
# arrival_date_year                0
# arrival_date_month               0
# arrival_date_day_of_month        0
# stays_in_weekend_nights          0
# stays_in_week_nights             0
# adults                           0
# children                         0
# country                        464
# market_segment                   0
# is_repeated_guest                0
# reserved_room_type               0
# assigned_room_type               0
# deposit_type                     0
# agent                         8213
# company                      36951
# customer_type                    0
# reservation_status               0
# reservation_status_date          0
# dtype: int64

# %%
# Booking transcation in july
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'arrival_date_year', 'arrival_date_month',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'country',
#        'market_segment', 'is_repeated_guest', 'reserved_room_type',
#        'assigned_room_type', 'deposit_type', 'agent', 'company',
#        'customer_type', 'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# How many bookings were made by Transient-Party (customer type) in the month of July?

# %%
booking_in_july = data[(data["customer_type"] == "Transient-Party") &
                       (data["arrival_date_month"] == "July")].shape(0)
# Out:
# 327

# %%
data.query("customer_type == 'Transient-Party' & arrival_date_month == 'July'").shape[0]
# Out:
# 327
